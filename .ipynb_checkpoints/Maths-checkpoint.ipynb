# %% [markdown]
# # Maths

# %% [markdown]
# Formula sheet - https://github.com/tarunluthra123/docs/blob/master/Useful%20maths%20formulas.md

# %% [markdown]
# ## Logarithm
# The exponent or power to which a base must be raised to yield a given number. Expressed mathematically, x is the logarithm of n to the base b if bx = n, in which case one writes x = logb n. For example, 23 = 8; therefore, 3 is the logarithm of 8 to base 2, or 3 = log<sub>2</sub> 8.
#
# <img src="https://media.giphy.com/media/iRBz7kiE3HsSA/giphy.gif" width="250" />
#
#
# Python functions for computing log :
# ```
# - math.log(x)    -> returns log(x) with base=e
# - math.log(x,a)  -> returns log(x) with base=a
# - math.log2(x)   -> returns log(x) with base=2
# - math.log10(x)  -> returns log(x) with base=10
# ```

# %%
import math

# %%
math.log(10)
# Out:
# 2.302585092994046

# %%
math.log(343, 7)
# Out:
# 3.0

# %%
math.log2(16)
# Out:
# 4.0

# %%
n = 100

while n > 1:
    print(n)
    n = n / 2
# Out:
# 100
# 50.0
# 25.0
# 12.5
# 6.25
# 3.125
# 1.5625

# %% [markdown]
# ## How many iterations would the above code snippet take ?
#
# Approx log<sub>2</sub>n

# %% [markdown]
# ## GCD

# %% [markdown]
# math module method -
# `math.gcd(*integers)`

# %%
math.gcd(2,3)
# Out:
# 1

# %%
math.gcd(10,15,40)
# Out:
# 5

# %%
a = int(input())
b = int(input())

def gcd(a,b):
    while a != 0:
        a, b = b % a, a
    return b
    
print("GCD is", gcd(a,b))
# Out:
# 10
# 10
# GCD is 10

# %% [markdown]
# ## LCM

# %% [markdown]
# math module method -
# `math.lcm(*integers)`

# %%
math.lcm(15,10,40)
# Out:
# 120

# %% [markdown]
# ## Prime Number - sqrt(N) method

# %%
def isPrime(n):
    """
    This function returns True or False based on primality check of n.
    Time complexity - O(sqrt(n))
    """
    
    if n == 1:
        return False
    
#     Search for factors in the range [2, sqrt(n)]
#     sq = n ** (1/2)
    sq = int(math.sqrt(n))

    for i in range(2, sq + 1):
        if n % i == 0:
            return False
        
    return True

# %%
isPrime(17)
# Out:
# True

# %%
isPrime(20)
# Out:
# False

# %%
isPrime(101)
# Out:
# True

# %%
isPrime(2)
# Out:
# True

# %%
isPrime(1)
# Out:
# False

# %%
10%4
# Out:
# 2

# %% [markdown]
# ## AP - Arithmatic Progression

# %% [markdown]
# ## GP - Geometric Progresssion

# %% [markdown]
# ## Combinations

# %% [markdown]
# math module method - \
# `math.comb(n, r)`

# %%
import math
math.comb(10, 4)
# Out:
# 210

# %%
def combination(n, r):
    num = math.factorial(n)
    den = math.factorial(r) * math.factorial(n-r)
    return num / den

# %%
combination(10, 4)
# Out:
# 210.0

# %% [markdown]
# ## Permutations
#
# math module method - \
# `math.perm(n, r)`

# %%
math.perm(10, 4)
# Out:
# 5040

# %%
def permutation(n, r):
    return math.factorial(n) / math.factorial(n-r)

# %%
permutation(10, 4)
# Out:
# 5040.0

# %% [markdown]
# ## Decimal to Binary

# %% [markdown]
# Using python inbuilt functionality:
# ```py
# def decimalToBinary(n):
#     return bin(n).replace("0b", "")
# ```
#
# Details - https://www.scaler.com/topics/convert-decimal-to-binary-in-python/

# %%
def decimalToBinary(n):
    return bin(n).replace("0b", "")

# %%
bin(20)
# Out:
# '0b10100'

# %%
def decimalToBinary(n):
    l = []
    while n > 0:
        remainder = n % 2
        l.append(str(remainder))
        n = n // 2
    
#     Reverse the list
    l = list(reversed(l))
    return "".join(l)

# %%
decimalToBinary(20)
# Out:
# '10100'

# %% [markdown]
# ## Break till 10.20 pm

# %% [markdown]
# ## Binary to Decimal

# %% [markdown]
# Using python inbuilt functionality:
# ```py
# def binaryToDecimal(x):
#     return int(x, 2)
# ```
#
# Details - https://www.scaler.com/topics/convert-decimal-to-binary-in-python/

# %%
# s is a binary string
def binaryToDecimal(s):
    i = 0
    result = 0
    
    for digit in s[::-1]:
        result += int(digit) * (2**i)
        i = i + 1
        
    return result

# %%
binaryToDecimal("10100")
# Out:
# 20

# %% [markdown]
# ## Problem - Trailing zeros in factorial
#
# Problem Link - [Trailing Zeros In Factorial](https://www.interviewbit.com/problems/trailing-zeros-in-factorial/)
#
# Youtube Video - [Trailing Zeros In Factorial](https://www.youtube.com/watch?v=wkvVdggCSeo&t=687s)

# %%
math.factorial(30)
# Out:
# 265252859812191058636308480000000

# %%
math.log(10**4)
# Out:
# 9.210340371976184

# %%
class Solution:
	# @param A : integer
	# @return an integer
	def trailingZeroes(self, A):
        result = 0
        den = 5

        x = A // den

        while x >= 1:
            result += x
            den *= 5
            x = A // den

        return result

# %%
# you are provided t number of testcases.
# for each testcase, take a number as input



t = int(input())

for i in range(t):
    n = int(input())

# %% [markdown]
# ## Magic Number Hint
# ![](https://scaler-production-new.s3.ap-southeast-1.amazonaws.com/attachments/attachments/000/004/615/original/Magic_Number_Hint.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIDNNIRGHAQUQRWYA%2F20220129%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Date=20220129T175601Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=b22c33d078f9f6346c88c06dc9a4ea5065f2568bf427e746a5e310f25fba9665)
